# %%
n=int(input())
i=0
test=0
while test<=n:
    test=2**i
    i+=1
l=n-(test//2)
ans=(2*l)+1
print(ans)
# Out:
# 41
# 19

# %%
n=int(input())
i=0
test=0
while (2**i)<=n:
    test=2**i
    i+=1
l=n-test
ans=(2*l)+1
print(ans)
# Out:
# 58963247
# 50817631

# %%
n=int(input())
s=0
for i in range(1,n):
    s+=(1/(i**2))
    print(s)
# Out:
# 20
# 1.0
# 1.25
# 1.3611111111111112
# 1.4236111111111112
# 1.4636111111111112
# 1.4913888888888889
# 1.511797052154195
# 1.527422052154195
# 1.5397677311665408
# 1.5497677311665408
# 1.558032193976458
# 1.5649766384209025
# 1.5708937981842162
# 1.5759958390005426
# 1.580440283444987
# 1.584346533444987
# 1.587806741057444
# 1.5908931608105303
# 1.5936632439130234

# %%
n=int(input())
s=0
for i in range(1,n):
    s+=(1/i)
    print(s)
# Out:
# 100
# 1.0
# 1.5
# 1.8333333333333333
# 2.083333333333333
# 2.283333333333333
# 2.4499999999999997
# 2.5928571428571425
# 2.7178571428571425
# 2.8289682539682537
# 2.9289682539682538
# 3.0198773448773446
# 3.103210678210678
# 3.180133755133755
# 3.251562326562327
# 3.3182289932289937
# 3.3807289932289937
# 3.439552522640758
# 3.4951080781963135
# 3.547739657143682
# 3.597739657143682
# 3.6453587047627294
# 3.690813250217275
# 3.73429151108684
# 3.7759581777535067
# 3.8159581777535068
# 3.854419716215045
# 3.8914567532520823
# 3.927171038966368
# 3.9616537975870574
# 3.9949871309203906
# 4.02724519543652
# 4.05849519543652
# 4.08879822573955
# 4.118209990445433
# 4.146781419016861
# 4.174559196794639
# 4.201586223821666
# 4.22790201329535
# 4.2535430389363755
# 4.278543038936376
# 4.302933282838815
# 4.326742806648339
# 4.349998620601827
# 4.3727258933290996
# 4.394948115551322
# 4.416687245986104
# 4.4379638417307845
# 4.4587971750641175
# 4.4792053383294235
# 4.499205338329423
# ...

# %%
import math
a=1.732
print(math.floor(a))
print(math.ceil(a))
# Out:
# 1
# 2

# %%
math.sqrt(5)
# Out:
# 2.23606797749979

# %%
s="haveaniceday"
print(s[0::4])
# Out:
# hae
